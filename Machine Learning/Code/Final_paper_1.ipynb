# %%
# !python3 code/train.py --seed=0 --trial=1 --kernel_size=5 --gpu=0 --logdir=modelM5 --epochs=5
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 32, 24, 24]             800
#        BatchNorm2d-2           [-1, 32, 24, 24]              64
#             Conv2d-3           [-1, 64, 20, 20]          51,200
#        BatchNorm2d-4           [-1, 64, 20, 20]             128
#             Conv2d-5           [-1, 96, 16, 16]         153,600
#        BatchNorm2d-6           [-1, 96, 16, 16]             192
#             Conv2d-7          [-1, 128, 12, 12]         307,200
#        BatchNorm2d-8          [-1, 128, 12, 12]             256
#             Conv2d-9            [-1, 160, 8, 8]         512,000
#       BatchNorm2d-10            [-1, 160, 8, 8]             320
#            Linear-11                   [-1, 10]         102,400
#       BatchNorm1d-12                   [-1, 10]              20
# ...
# Total params: 1,128,180
# Trainable params: 1,128,180
# ...

# %%
# !python3 code/test.py  --seed=0 --trial=1 --kernel_size=5 --logdir=modelM5

# %%
# !python3 code/homo_ensemble.py --kernel_size=5
# Out:
#    1   50    0    0
#    2   50    0    0
#    3   50    0    0
#    4   50    0    0
#    5   50    0    0
#    6   50    0    0
#    7   50    0    0
#    8   50    0    0
#    9   50    0    0
#   10   50    0    0
#   11   50    0    0
#   12   50    0    0
#   13   50    0    0
#   14   50    0    0
#   15   50    0    0
#   16   50    0    0
#   17   50    0    0
#   18   50    0    0
#   19   50    0    0
#   20   50    0    0
#   21   50    0    0
#   22   50    0    0
#   23   50    0    0
#   24   50    0    0
#   25   50    0    0
#   26   50    0    0
#   27   50    0    0
#   28   50    0    0
#   29   50    0    0
#   30   50    0    0
#   31   50    0    0
#   32   50    0    0
#   33   50    0    0
#   34   50    0    0
#   35   50    0    0
#   36   50    0    0
#   37   50    0    0
#   38   50    0    0
#   39   50    0    0
#   40   50    0    0
#   41   50    0    0
#   42   50    0    0
#   43   50    0    0
#   44   50    0    0
#   45   50    0    0
# ...
